# %%
import pandas as pd

# %%
data_frame=pd.read_csv("/home/parameswar/Documents/Anukai solutions/projects/DEAP project/Amigos /joined_data_1.csv")

# %%
data_frame.head()
# Out:
#    9.736634779916856e-06  5.787642152785703e-06  -1.073473183672229e-05  \
# 0              -4.134229              -4.423547               -2.490549
# 1             -18.220059              -2.914807               -5.201815
# 2             -25.212780              -3.057979               -4.947938
# 3             -16.565983              -7.602091               -3.964297
# 4             -16.187689              -6.622140               -5.658407
#
#    -9.849840580268248e-06  7.438558749594238e-06  -5.887640514846929e-06  \
# 0               -1.582867             -10.492586                2.332734
# 1              -12.105780              -1.722718               10.596031
# 2              -12.999582               3.850498               10.537365
# 3               -8.039483             -11.396888                5.559927
# 4              -13.454876             -22.158338                7.125542
#
#    -4.61973652750445e-06  5.549910107898888e-06  1.495258796002615e-06  \
# ...

# %%
data_frame.shape
# Out:
# (12224, 17)

# %%
data_frame.columns
# Out:
# Index(['9.736634779916856e-06', '5.787642152785703e-06',
#        '-1.073473183672229e-05', '-9.849840580268248e-06',
#        '7.438558749594238e-06', '-5.887640514846929e-06',
#        '-4.61973652750445e-06', '5.549910107898888e-06',
#        '1.495258796002615e-06', '-1.119793185343162e-06',
#        '-7.657423144574311e-06', '8.084774741898374e-07',
#        '1.574502810660721e-06', '7.478180775028541e-06', '-16.64023364600503',
#        '-11.55550375070384', '-8940.09936786101'],
#       dtype='object')

# %%
data=data_frame["-8940.09936786101"]

# %%
len(data)
# Out:
# 12224

# %%
import matplotlib.pyplot as plt
N=[i for i in range(0,12224)]
plt.figure(figsize=(30,10))
plt.plot(N,data,c="green",lw=3)
plt.title("Amigos_gsr_values_for_1_video")
plt.legend(["GSR"])
plt.savefig("/home/parameswar/Documents/Anukai solutions/projects/DEAP project/Amigos /gsr.jpg")
plt.show()

# %%
data_frame=pd.read_csv("data_1_p_v_p_c.csv")

# %%
data_frame.columns
# Out:
# Index(['Fp1', 'AF3', 'F3', 'F7', 'FC5', 'FC1', 'C3', 'T7', 'CP5', 'CP1', 'P3',
#        'P7', 'PO3', 'O1', 'Oz', 'Pz', 'Fp2', 'AF4', 'Fz', 'F4', 'F8', 'FC6',
#        'FC2', 'Cz', 'C4', 'T8', 'CP6', 'CP2', 'P4', 'P8', 'PO4', 'O2', 'hEOG',
#        'vEOG', 'zEMG', 'tEMG', 'GSR', 'Respiration belt', 'Plethysmograph',
#        'Temperature'],
#       dtype='object')

# %%
data=data_frame["GSR"]

# %%
len(data)
# Out:
# 8064

# %%
import matplotlib.pyplot as plt
N=[i for i in range(0,8064)]
plt.figure(figsize=(30,10))
plt.plot(N,data,c="green",lw=3)
plt.title("Deap_gsr_values_for_1_video")
plt.legend(["GSR"])
plt.savefig("gsr_deap.jpg")
plt.show()
